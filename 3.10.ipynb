# %% [markdown]
# ### Question 3.10
# A sociologist employed a first-order simple linear regression model to relate per capita earnings \(Y\) to average number of years of schooling \(X\) for 12 cities.

# %%
# Load libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loada data
CH03PR10 = pd.read_excel("C:\\Users\\kwame\\Downloads\\CH03PR10.xlsx")

# %% [markdown]
# #### a. The plot of the fitted values versus the semistudentized residuals shows that most of them are between \(+ or - 2\), with the exception of one unusually large point.

# %%
# Create a scatterplot
plt.scatter(CH03PR10['Yhat'], CH03PR10['estar'])

# Add a horizontal reference line at y = 0
plt.axhline(y=0, color='red')  # You can change the line color if desired

# Label the axes (optional)
plt.xlabel('Yhat')
plt.ylabel('estar')

# Show the plot
plt.show()

# %% [markdown]
# #### b. There are four out of 12 observations that are outside \(+ or - 1 \) standard deviation (33%), which is what we would expect in a normal distribution.

# %%
# Calculate the sum of absolute values of 'estar' greater than 1
result = (CH03PR10['estar'].abs() > 1).sum()

print(result)
# Out:
# 4
